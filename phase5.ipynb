# %%
#  Callbacks + Model Training 

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.datasets import fashion_mnist
import os, datetime

# ------------------------------
# Load and preprocess data
# ------------------------------
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

X_train = X_train.reshape(-1, 28 * 28)
X_test = X_test.reshape(-1, 28 * 28)

X_val = X_train[:9000]
y_val = y_train[:9000]
X_train = X_train[9000:]
y_train = y_train[9000:]

# ------------------------------
# Define the model
# ------------------------------
model = keras.Sequential([
    layers.Dense(256, activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Dropout(0.4),

    layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(10, activation="softmax")
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# ------------------------------
# Create directories for logs/checkpoints
# ------------------------------
base_dir = "training_logs"
os.makedirs(base_dir, exist_ok=True)

timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = os.path.join(base_dir, "tensorboard", timestamp)
checkpoint_path = os.path.join(base_dir, "checkpoints", f"best_model_{timestamp}.keras")
os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)

# ------------------------------
# Define callbacks
# ------------------------------
tensorboard_cb = keras.callbacks.TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    write_graph=True,
    write_images=True
)

checkpoint_cb = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

earlystop_cb = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_cb = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

callbacks = [tensorboard_cb, checkpoint_cb, earlystop_cb, reduce_lr_cb]

# ------------------------------
# Train the model with callbacks
# ------------------------------
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=128,
    callbacks=callbacks,
    verbose=2
)
# Out:
# Epoch 1/50
#
# Epoch 1: val_loss improved from None to 0.83790, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 6s - 16ms/step - accuracy: 0.7804 - loss: 1.0732 - val_accuracy: 0.8267 - val_loss: 0.8379 - learning_rate: 1.0000e-03
# Epoch 2/50
#
# Epoch 2: val_loss improved from 0.83790 to 0.81287, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.8265 - loss: 0.7903 - val_accuracy: 0.8012 - val_loss: 0.8129 - learning_rate: 1.0000e-03
# Epoch 3/50
#
# Epoch 3: val_loss improved from 0.81287 to 0.66862, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.8348 - loss: 0.6818 - val_accuracy: 0.8303 - val_loss: 0.6686 - learning_rate: 1.0000e-03
# Epoch 4/50
#
# Epoch 4: val_loss improved from 0.66862 to 0.55919, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 7ms/step - accuracy: 0.8377 - loss: 0.6135 - val_accuracy: 0.8482 - val_loss: 0.5592 - learning_rate: 1.0000e-03
# Epoch 5/50
#
# Epoch 5: val_loss improved from 0.55919 to 0.53764, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 7ms/step - accuracy: 0.8401 - loss: 0.5740 - val_accuracy: 0.8478 - val_loss: 0.5376 - learning_rate: 1.0000e-03
# Epoch 6/50
#
# Epoch 6: val_loss improved from 0.53764 to 0.48167, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 7ms/step - accuracy: 0.8435 - loss: 0.5432 - val_accuracy: 0.8633 - val_loss: 0.4817 - learning_rate: 1.0000e-03
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 0.48167
# 399/399 - 3s - 7ms/step - accuracy: 0.8474 - loss: 0.5214 - val_accuracy: 0.8571 - val_loss: 0.4860 - learning_rate: 1.0000e-03
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 0.48167
# 399/399 - 3s - 8ms/step - accuracy: 0.8441 - loss: 0.5217 - val_accuracy: 0.8456 - val_loss: 0.5098 - learning_rate: 1.0000e-03
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 0.48167
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 399/399 - 3s - 8ms/step - accuracy: 0.8457 - loss: 0.5145 - val_accuracy: 0.8456 - val_loss: 0.5042 - learning_rate: 1.0000e-03
# Epoch 10/50
#
# Epoch 10: val_loss improved from 0.48167 to 0.42989, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.8594 - loss: 0.4730 - val_accuracy: 0.8742 - val_loss: 0.4299 - learning_rate: 5.0000e-04
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 0.42989
# 399/399 - 3s - 8ms/step - accuracy: 0.8629 - loss: 0.4554 - val_accuracy: 0.8623 - val_loss: 0.4502 - learning_rate: 5.0000e-04
# Epoch 12/50
#
# Epoch 12: val_loss improved from 0.42989 to 0.42522, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.8613 - loss: 0.4501 - val_accuracy: 0.8719 - val_loss: 0.4252 - learning_rate: 5.0000e-04
# Epoch 13/50
#
# Epoch 13: val_loss improved from 0.42522 to 0.41948, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.8634 - loss: 0.4440 - val_accuracy: 0.8733 - val_loss: 0.4195 - learning_rate: 5.0000e-04
# Epoch 14/50
#
# Epoch 14: val_loss did not improve from 0.41948
# 399/399 - 3s - 8ms/step - accuracy: 0.8630 - loss: 0.4430 - val_accuracy: 0.8684 - val_loss: 0.4228 - learning_rate: 5.0000e-04
# Epoch 15/50
#
# Epoch 15: val_loss did not improve from 0.41948
# 399/399 - 3s - 8ms/step - accuracy: 0.8647 - loss: 0.4343 - val_accuracy: 0.8626 - val_loss: 0.4510 - learning_rate: 5.0000e-04
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 0.41948
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 399/399 - 2s - 6ms/step - accuracy: 0.8644 - loss: 0.4333 - val_accuracy: 0.8631 - val_loss: 0.4449 - learning_rate: 5.0000e-04
# Epoch 17/50
#
# Epoch 17: val_loss improved from 0.41948 to 0.37787, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 6ms/step - accuracy: 0.8757 - loss: 0.4019 - val_accuracy: 0.8831 - val_loss: 0.3779 - learning_rate: 2.5000e-04
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 0.37787
# 399/399 - 2s - 6ms/step - accuracy: 0.8789 - loss: 0.3894 - val_accuracy: 0.8789 - val_loss: 0.3858 - learning_rate: 2.5000e-04
# Epoch 19/50
#
# Epoch 19: val_loss improved from 0.37787 to 0.37016, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 6ms/step - accuracy: 0.8780 - loss: 0.3862 - val_accuracy: 0.8829 - val_loss: 0.3702 - learning_rate: 2.5000e-04
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.37016
# 399/399 - 2s - 6ms/step - accuracy: 0.8796 - loss: 0.3818 - val_accuracy: 0.8814 - val_loss: 0.3756 - learning_rate: 2.5000e-04
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 0.37016
# 399/399 - 2s - 6ms/step - accuracy: 0.8827 - loss: 0.3747 - val_accuracy: 0.8748 - val_loss: 0.3953 - learning_rate: 2.5000e-04
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.37016
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 399/399 - 2s - 6ms/step - accuracy: 0.8814 - loss: 0.3725 - val_accuracy: 0.8806 - val_loss: 0.3753 - learning_rate: 2.5000e-04
# Epoch 23/50
#
# Epoch 23: val_loss improved from 0.37016 to 0.35256, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 2s - 6ms/step - accuracy: 0.8889 - loss: 0.3509 - val_accuracy: 0.8886 - val_loss: 0.3526 - learning_rate: 1.2500e-04
# Epoch 24/50
#
# Epoch 24: val_loss improved from 0.35256 to 0.35107, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 6ms/step - accuracy: 0.8902 - loss: 0.3449 - val_accuracy: 0.8884 - val_loss: 0.3511 - learning_rate: 1.2500e-04
# Epoch 25/50
#
# Epoch 25: val_loss improved from 0.35107 to 0.34852, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 6ms/step - accuracy: 0.8923 - loss: 0.3413 - val_accuracy: 0.8894 - val_loss: 0.3485 - learning_rate: 1.2500e-04
# Epoch 26/50
#
# Epoch 26: val_loss improved from 0.34852 to 0.34844, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 6ms/step - accuracy: 0.8912 - loss: 0.3391 - val_accuracy: 0.8877 - val_loss: 0.3484 - learning_rate: 1.2500e-04
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.34844
# 399/399 - 2s - 6ms/step - accuracy: 0.8946 - loss: 0.3346 - val_accuracy: 0.8886 - val_loss: 0.3486 - learning_rate: 1.2500e-04
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.34844
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 399/399 - 2s - 6ms/step - accuracy: 0.8945 - loss: 0.3306 - val_accuracy: 0.8811 - val_loss: 0.3585 - learning_rate: 1.2500e-04
# Epoch 29/50
#
# Epoch 29: val_loss improved from 0.34844 to 0.33823, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.8970 - loss: 0.3215 - val_accuracy: 0.8926 - val_loss: 0.3382 - learning_rate: 6.2500e-05
# Epoch 30/50
#
# Epoch 30: val_loss improved from 0.33823 to 0.33696, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.8981 - loss: 0.3157 - val_accuracy: 0.8920 - val_loss: 0.3370 - learning_rate: 6.2500e-05
# Epoch 31/50
#
# Epoch 31: val_loss improved from 0.33696 to 0.33371, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.9010 - loss: 0.3141 - val_accuracy: 0.8938 - val_loss: 0.3337 - learning_rate: 6.2500e-05
# Epoch 32/50
#
# Epoch 32: val_loss improved from 0.33371 to 0.33353, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.8996 - loss: 0.3140 - val_accuracy: 0.8941 - val_loss: 0.3335 - learning_rate: 6.2500e-05
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 0.33353
# 399/399 - 3s - 8ms/step - accuracy: 0.9005 - loss: 0.3108 - val_accuracy: 0.8926 - val_loss: 0.3343 - learning_rate: 6.2500e-05
# Epoch 34/50
#
# Epoch 34: val_loss improved from 0.33353 to 0.33243, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.9020 - loss: 0.3050 - val_accuracy: 0.8948 - val_loss: 0.3324 - learning_rate: 6.2500e-05
# Epoch 35/50
#
# Epoch 35: val_loss improved from 0.33243 to 0.33138, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 7ms/step - accuracy: 0.9036 - loss: 0.3031 - val_accuracy: 0.8928 - val_loss: 0.3314 - learning_rate: 6.2500e-05
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 0.33138
# 399/399 - 3s - 7ms/step - accuracy: 0.9029 - loss: 0.2998 - val_accuracy: 0.8950 - val_loss: 0.3315 - learning_rate: 6.2500e-05
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 0.33138
# 399/399 - 3s - 7ms/step - accuracy: 0.9029 - loss: 0.3018 - val_accuracy: 0.8946 - val_loss: 0.3332 - learning_rate: 6.2500e-05
# Epoch 38/50
#
# Epoch 38: val_loss improved from 0.33138 to 0.33098, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 7ms/step - accuracy: 0.9053 - loss: 0.2967 - val_accuracy: 0.8944 - val_loss: 0.3310 - learning_rate: 6.2500e-05
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 0.33098
# 399/399 - 3s - 7ms/step - accuracy: 0.9041 - loss: 0.2979 - val_accuracy: 0.8950 - val_loss: 0.3321 - learning_rate: 6.2500e-05
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 0.33098
# 399/399 - 3s - 7ms/step - accuracy: 0.9038 - loss: 0.2948 - val_accuracy: 0.8919 - val_loss: 0.3328 - learning_rate: 6.2500e-05
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 0.33098
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 399/399 - 3s - 8ms/step - accuracy: 0.9068 - loss: 0.2922 - val_accuracy: 0.8953 - val_loss: 0.3331 - learning_rate: 6.2500e-05
# Epoch 42/50
#
# Epoch 42: val_loss improved from 0.33098 to 0.32667, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.9094 - loss: 0.2859 - val_accuracy: 0.8966 - val_loss: 0.3267 - learning_rate: 3.1250e-05
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 0.32667
# 399/399 - 3s - 8ms/step - accuracy: 0.9100 - loss: 0.2846 - val_accuracy: 0.8949 - val_loss: 0.3273 - learning_rate: 3.1250e-05
# Epoch 44/50
#
# Epoch 44: val_loss improved from 0.32667 to 0.32316, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.9087 - loss: 0.2833 - val_accuracy: 0.8957 - val_loss: 0.3232 - learning_rate: 3.1250e-05
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 0.32316
# 399/399 - 3s - 8ms/step - accuracy: 0.9097 - loss: 0.2811 - val_accuracy: 0.8938 - val_loss: 0.3261 - learning_rate: 3.1250e-05
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 0.32316
# 399/399 - 3s - 8ms/step - accuracy: 0.9097 - loss: 0.2801 - val_accuracy: 0.8951 - val_loss: 0.3237 - learning_rate: 3.1250e-05
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 0.32316
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 399/399 - 3s - 8ms/step - accuracy: 0.9101 - loss: 0.2770 - val_accuracy: 0.8959 - val_loss: 0.3253 - learning_rate: 3.1250e-05
# Epoch 48/50
#
# Epoch 48: val_loss improved from 0.32316 to 0.32118, saving model to training_logs\checkpoints\best_model_20251028-113151.keras
# 399/399 - 3s - 8ms/step - accuracy: 0.9122 - loss: 0.2737 - val_accuracy: 0.8972 - val_loss: 0.3212 - learning_rate: 1.5625e-05
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 0.32118
# 399/399 - 3s - 7ms/step - accuracy: 0.9128 - loss: 0.2735 - val_accuracy: 0.8961 - val_loss: 0.3228 - learning_rate: 1.5625e-05
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 0.32118
# 399/399 - 3s - 7ms/step - accuracy: 0.9128 - loss: 0.2712 - val_accuracy: 0.8959 - val_loss: 0.3219 - learning_rate: 1.5625e-05
# Restoring model weights from the end of the best epoch: 48.
